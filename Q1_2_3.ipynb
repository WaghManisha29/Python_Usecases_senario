# %%
import pandas as pd

customer=r"c:\Users\Manisha\Downloads\customer_data_us.csv"

customer_data=pd.read_csv(customer,index_col='customer_id')

customer_dataframe=pd.DataFrame(customer_data)

customer_dataframe
# Out:
#                          name                        email         phone  \
# customer_id
# 1               Michelle Kidd           vayala@example.net  619-723-4258
# 2                 Brad Newton  taylorcatherine@example.net  537-674-1158
# 3                Larry Torres         dsanchez@example.net  810-256-4505
# 4              Kimberly Price    jessicaknight@example.com  423-222-9779
# 5            Matthew Phillips        qwilliams@example.com  220-763-3522
# ...                       ...                          ...           ...
# 996            Jerry Mcdaniel       walkerlisa@example.net  638-989-9441
# 997              Jodi Simpson           eric24@example.org  483-625-2940
# 998             Crystal Brown         pshaffer@example.net  390-747-3088
# 999            Gregory Duarte    caitlindunlap@example.org  257-409-8196
# 1000              Jason Walls        michael42@example.com  692-333-6880
#
#                                                        address  \
# ...

# %%
customer_data.isnull().sum()
# Out:
# name                  0
# email                50
# phone                16
# address               0
# registration_date     0
# loyalty_status        0
# dtype: int64

# %%
customer_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 1 to 1000
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               1000 non-null   object
#  1   email              950 non-null    object
#  2   phone              984 non-null    object
#  3   address            1000 non-null   object
#  4   registration_date  1000 non-null   object
#  5   loyalty_status     1000 non-null   object
# dtypes: object(6)
# memory usage: 54.7+ KB

# %%
customer_dataframe["name"].duplicated().any()
customer_dataframe["email"].duplicated().any()
# Out:
# np.True_

# %%
customer_dataframe["email"]=customer_dataframe["email"].fillna('null@null.com')

customer_dataframe.loc[36]
# Out:
# name                                                 Christopher Clark
# email                                                    null@null.com
# phone                                                     119-609-3438
# address              2325 Danielle Knolls Suite 719, Gabrielleview,...
# registration_date                                           13-01-2024
# loyalty_status                                                    Gold
# Name: 36, dtype: object

# %%
def format_phone(phone):
    # Convert to string and remove non-digit characters manually
    phone = str(phone)
    digits = ''.join([ch for ch in phone if ch.isdigit()])

    # Format only if exactly 10 digits
    if len(digits) == 10:
        return f"({digits[:3]}) {digits[3:6]}-{digits[6:]}"          # (XXX) XXX-XXXX
        # return f"{digits[:3]}.{digits[3:6]}.{digits[6:]}"          # XXX.XXX.XXXX
        # return f"{digits[:3]}-{digits[3:6]}-{digits[6:]}"          # XXX-XXX-XXXX
        # return f"{digits[:3]} {digits[3:6]} {digits[6:]}"          # XXX XXX XXXX
    else:
        return "000-000-0000"


# Apply to 'phone' column
customer_dataframe["phone"]=customer_dataframe["phone"].apply(format_phone)



customer_dataframe.loc[297]
# Out:
# name                                                    Bryan Marshall
# email                                             daniel62@example.net
# phone                                                     000-000-0000
# address              86370 Charles Loop Apt. 517, Madelineborough, ...
# registration_date                                           30-06-2024
# loyalty_status                                                  Silver
# Name: 297, dtype: object

# %%
customer_dataframe.isnull().sum()

customer_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 1 to 1000
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               1000 non-null   object
#  1   email              1000 non-null   object
#  2   phone              1000 non-null   object
#  3   address            1000 non-null   object
#  4   registration_date  1000 non-null   object
#  5   loyalty_status     1000 non-null   object
# dtypes: object(6)
# memory usage: 87.0+ KB

# %%
customer_dataframe.to_csv("replaced_customer.csv")

# %%
customer_dataframe["phone"]
# Out:
# customer_id
# 1       (619) 723-4258
# 2       (537) 674-1158
# 3       (810) 256-4505
# 4       (423) 222-9779
# 5       (220) 763-3522
#              ...
# 996     (638) 989-9441
# 997     (483) 625-2940
# 998     (390) 747-3088
# 999     (257) 409-8196
# 1000    (692) 333-6880
# Name: phone, Length: 1000, dtype: object

# %%
customer_dataframe
# Out:
#                          name                        email           phone  \
# customer_id
# 1               Michelle Kidd           vayala@example.net  (619) 723-4258
# 2                 Brad Newton  taylorcatherine@example.net  (537) 674-1158
# 3                Larry Torres         dsanchez@example.net  (810) 256-4505
# 4              Kimberly Price    jessicaknight@example.com  (423) 222-9779
# 5            Matthew Phillips        qwilliams@example.com  (220) 763-3522
# ...                       ...                          ...             ...
# 996            Jerry Mcdaniel       walkerlisa@example.net  (638) 989-9441
# 997              Jodi Simpson           eric24@example.org  (483) 625-2940
# 998             Crystal Brown         pshaffer@example.net  (390) 747-3088
# 999            Gregory Duarte    caitlindunlap@example.org  (257) 409-8196
# 1000              Jason Walls        michael42@example.com  (692) 333-6880
#
# ...

# %%
customer_dataframe["registration_date"].unique()
# Out:
# array(['25-01-2025', '13-07-2023', '18-08-2023', '08-12-2024',
#        '03-02-2024', '03-03-2025', '30-09-2024', '06-10-2023',
#        '31-10-2024', '25-02-2024', '08-03-2025', '18-04-2024',
#        '28-04-2024', '09-05-2024', '04-12-2024', '12-11-2023',
#        '24-06-2024', '27-01-2025', '21-02-2025', '22-02-2025',
#        '13-06-2024', '24-10-2024', '29-03-2025', '07-08-2023',
#        '13-06-2025', '10-03-2024', '01-08-2024', '07-04-2024',
#        '04-11-2024', '15-12-2024', '18-09-2023', '02-12-2024',
#        '02-08-2024', '09-06-2024', '13-11-2024', '13-01-2024',
#        '13-08-2024', '05-07-2024', '14-06-2025', '24-11-2024',
#        '19-11-2024', '12-06-2025', '13-01-2025', '24-06-2023',
#        '23-10-2023', '22-04-2024', '03-12-2023', '17-08-2023',
#        '06-04-2025', '24-10-2023', '25-10-2024', '30-05-2024',
#        '25-05-2025', '27-04-2025', '18-02-2024', '06-06-2025',
#        '23-01-2025', '01-10-2024', '17-07-2024', '05-04-2024',
# ...

# %%
import pandas as pd

tran=r"C:\Users\Manisha\Downloads\transaction_data.csv"
transaction=pd.read_csv(tran)
transaction.head(3)
# Out:
#    transaction_id  customer_id   amount     transaction_date product_category  \
# 0               1          565  2992.47  2025-03-10 01:20:54           Sports
# 1               2          323  2041.87  2025-01-02 15:24:19         Clothing
# 2               3          398   107.35  2025-02-16 03:49:01           Beauty
#
#   payment_method store_location
# 0     Debit Card       New York
# 1           Cash       New York
# 2     Debit Card         Online

# %%
merge_table=pd.merge(customer_dataframe,transaction,on='customer_id',how='inner')
merge_table.head()
# Out:
#    customer_id              name                        email           phone  \
# 0            1     Michelle Kidd           vayala@example.net  (619) 723-4258
# 1            4    Kimberly Price    jessicaknight@example.com  (423) 222-9779
# 2            5  Matthew Phillips        qwilliams@example.com  (220) 763-3522
# 3            7      Louis Miller  patriciaelliott@example.org  (198) 862-7105
# 4            7      Louis Miller  patriciaelliott@example.org  (198) 862-7105
#
#                                              address registration_date  \
# 0                        USNS Santiago, FPO AE 80872        25-01-2025
# 1         1631 Alexis Meadows, Lake Amanda, CA 75179        08-12-2024
# 2  2274 Williams Heights Suite 895, Andersonhaven...        03-02-2024
# 3        02590 Marshall Well, Sheppardland, CT 88067        30-09-2024
# 4        02590 Marshall Well, Sheppardland, CT 88067        30-09-2024
#
#   loyalty_status  transaction_id   amount     transaction_date  \
# ...

# %%
merge_table.isnull().sum()
# Out:
# customer_id           0
# name                  0
# email                 0
# phone                 0
# address               0
# registration_date     0
# loyalty_status        0
# transaction_id        0
# amount               50
# transaction_date      0
# product_category      0
# payment_method        0
# store_location        0
# dtype: int64

# %%
merge_table['amount']=merge_table['amount'].fillna(merge_table['amount'].mean())
merge_table.isnull().sum()
# Out:
# customer_id          0
# name                 0
# email                0
# phone                0
# address              0
# registration_date    0
# loyalty_status       0
# transaction_id       0
# amount               0
# transaction_date     0
# product_category     0
# payment_method       0
# store_location       0
# dtype: int64

# %%
high_transaction=merge_table[merge_table['amount']>1000]
high_transaction
# Out:
#      customer_id              name                        email  \
# 0              1     Michelle Kidd           vayala@example.net
# 1              4    Kimberly Price    jessicaknight@example.com
# 2              5  Matthew Phillips        qwilliams@example.com
# 3              7      Louis Miller  patriciaelliott@example.org
# 6             10      Rachel White     whitemichael@example.org
# ..           ...               ...                          ...
# 991          991     Erica Fleming          erica85@example.net
# 992          992    Thomas Stevens    vargasmatthew@example.org
# 993          995    Deanna Johnson            ycook@example.org
# 994          995    Deanna Johnson            ycook@example.org
# 999          998     Crystal Brown         pshaffer@example.net
#
#               phone                                            address  \
# 0    (619) 723-4258                        USNS Santiago, FPO AE 80872
# ...
